# %% [markdown]
# #### Note for data fields:
# - Age: Age in years when a woman is pregnant.
# - SystolicBP: Upper value of Blood Pressure in mmHg, another significant attribute during pregnancy.
# - DiastolicBP: Lower value of Blood Pressure in mmHg, another significant attribute during pregnancy.
# - BS: Blood glucose levels is in terms of a molar concentration, mmol/L.
# - HeartRate: A normal resting heart rate in beats per minute.
# - Risk Level: Predicted Risk Intensity Level during pregnancy considering the previous attribute.

# %% [markdown]
#  Load library

# %%
import pandas as pd

# %% [markdown]
# Read the data

# %%
df=pd.read_csv('Maternal Health Risk Data Set.csv')

# %% [markdown]
# Explore the data set

# %%
# rows and columns
df.shape
# Out:
# (1014, 7)

# %%
# first 5 lines
df.head()
# Out:
#    Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel
# 0   25         130           80  15.0      98.0         86  high risk
# 1   35         140           90  13.0      98.0         70  high risk
# 2   29          90           70   8.0     100.0         80  high risk
# 3   30         140           85   7.0      98.0         70  high risk
# 4   35         120           60   6.1      98.0         76   low risk

# %%
# data structure
df.dtypes
# Out:
# Age              int64
# SystolicBP       int64
# DiastolicBP      int64
# BS             float64
# BodyTemp       float64
# HeartRate        int64
# RiskLevel       object
# dtype: object

# %%
# check missing data
df.isnull().sum()
# Out:
# Age            0
# SystolicBP     0
# DiastolicBP    0
# BS             0
# BodyTemp       0
# HeartRate      0
# RiskLevel      0
# dtype: int64

# %%
# descriptive summary
df.describe()
# Out:
#                Age   SystolicBP  DiastolicBP           BS     BodyTemp  \
# count  1014.000000  1014.000000  1014.000000  1014.000000  1014.000000
# mean     29.871795   113.198225    76.460552     8.725986    98.665089
# std      13.474386    18.403913    13.885796     3.293532     1.371384
# min      10.000000    70.000000    49.000000     6.000000    98.000000
# 25%      19.000000   100.000000    65.000000     6.900000    98.000000
# 50%      26.000000   120.000000    80.000000     7.500000    98.000000
# 75%      39.000000   120.000000    90.000000     8.000000    98.000000
# max      70.000000   160.000000   100.000000    19.000000   103.000000
#
#          HeartRate
# count  1014.000000
# mean     74.301775
# std       8.088702
# min       7.000000
# 25%      70.000000
# 50%      76.000000
# 75%      80.000000
# max      90.000000

# %%
# convert risk level to categorical variable
df['RiskLevel']=pd.Categorical(df['RiskLevel'],['high risk','mid risk','low risk'])

# %%
# count records by risk level
df['RiskLevel'].value_counts()
# Out:
# low risk     406
# mid risk     336
# high risk    272
# Name: RiskLevel, dtype: int64

# %%
# Average value of health indicators by risk level
df.groupby('RiskLevel').mean()
# Out:
#                  Age  SystolicBP  DiastolicBP         BS   BodyTemp  HeartRate
# RiskLevel
# high risk  36.216912  124.194853    85.073529  12.122610  98.899265  76.742647
# mid risk   28.363095  113.154762    74.232143   7.795744  98.833333  74.175595
# low risk   26.869458  105.866995    72.534483   7.220271  98.368966  72.770936

# %%
# return without index of risk level
df.groupby('RiskLevel',as_index=False).mean()
# Out:
#    RiskLevel        Age  SystolicBP  DiastolicBP         BS   BodyTemp  \
# 0  high risk  36.216912  124.194853    85.073529  12.122610  98.899265
# 1   mid risk  28.363095  113.154762    74.232143   7.795744  98.833333
# 2   low risk  26.869458  105.866995    72.534483   7.220271  98.368966
#
#    HeartRate
# 0  76.742647
# 1  74.175595
# 2  72.770936

# %%
# reorder the risk level
# df.groupby('RiskLevel').mean().reindex(index=['high risk','mid risk','low risk'])

# %%
# define peak to peak function
def peak_to_peak(df):
    return df.max() - df.min()

# %%
# min, max and peak to peak values by risk level
df.groupby('RiskLevel').agg(['min','max',peak_to_peak])
# Out:
#           Age                  SystolicBP                   DiastolicBP       \
#           min max peak_to_peak        min  max peak_to_peak         min  max
# RiskLevel
# high risk  12  65           53         83  160           77          60  100
# mid risk   10  60           50         70  140           70          50  100
# low risk   10  70           60         70  129           59          49  100
#
#                          BS                    BodyTemp                      \
#           peak_to_peak  min   max peak_to_peak      min    max peak_to_peak
# RiskLevel
# high risk           40  6.1  19.0         12.9     98.0  103.0          5.0
# mid risk            50  6.0  18.0         12.0     98.0  103.0          5.0
# low risk            51  6.0  11.0          5.0     98.0  103.0          5.0
#
#           HeartRate
#                 min max peak_to_peak
# RiskLevel
# high risk        60  90           30
# mid risk         60  88           28
# low risk          7  88           81

# %%
# rename the column of peak_to_peak
df.groupby('RiskLevel').agg(['min','max',('max-min',peak_to_peak)])
# Out:
#           Age             SystolicBP              DiastolicBP               \
#           min max max-min        min  max max-min         min  max max-min
# RiskLevel
# high risk  12  65      53         83  160      77          60  100      40
# mid risk   10  60      50         70  140      70          50  100      50
# low risk   10  70      60         70  129      59          49  100      51
#
#             BS               BodyTemp                HeartRate
#            min   max max-min      min    max max-min       min max max-min
# RiskLevel
# high risk  6.1  19.0    12.9     98.0  103.0     5.0        60  90      30
# mid risk   6.0  18.0    12.0     98.0  103.0     5.0        60  88      28
# low risk   6.0  11.0     5.0     98.0  103.0     5.0         7  88      81

# %%
# count the patients number by age
df.groupby('Age')[['Age']].count().rename(columns={'Age':'No. of Patients'})
# Out:
#      No. of Patients
# Age
# 10                 4
# 12                35
# 13                12
# 14                 3
# 15                60
# 16                16
# 17                63
# 18                19
# 19                67
# 20                22
# 21                38
# 22                45
# 23                71
# 24                 3
# 25                48
# 26                 3
# 27                 9
# 28                28
# 29                40
# 30                30
# 31                22
# 32                48
# 33                 5
# 34                 5
# 35                50
# 36                 4
# 37                 6
# 38                 2
# 39                 4
# 40                37
# 41                 1
# 42                23
# 43                 5
# 44                 3
# 45                 9
# 46                 1
# 48                26
# 49                 9
# 50                43
# 51                 1
# 54                12
# 55                37
# 56                 1
# 59                 2
# 60                34
# 62                 1
# 63                 2
# 65                 3
# 66                 1
# 70                 1

# %%
# Add a new column 'age group'
def age_group(row):
   if row['Age']>=10 and row['Age']<20:
      return '10-20'
   elif row['Age']>=20 and row['Age']<30:
      return '20-30'
   elif row['Age']>=30 and row['Age']<40:
      return '30-40'      
   elif row['Age']>=40 and row['Age']<50:
      return '40-50'   
   else:
      return '50+'

df['Age_Group']=df.apply(age_group,axis=1)

# %%
# check the unique values of age group in data frame
df['Age_Group'].unique()
# Out:
# array(['20-30', '30-40', '40-50', '10-20', '50+'], dtype=object)

# %%
# group by risk level and age group
df.loc[:,df.columns!='Age'].groupby(['Age_Group','RiskLevel']).mean().unstack()
# Out:
#            SystolicBP                         DiastolicBP             \
# RiskLevel   high risk    mid risk    low risk   high risk   mid risk
# Age_Group
# 10-20       95.128205  106.039604   98.992806   66.410256  71.504950
# 20-30      122.739130  113.541667  106.156028   83.152174  73.250000
# 30-40      127.089552  117.181818  114.074074   86.567164  72.545455
# 40-50      130.983607  122.105263  118.235294   89.918033  85.263158
# 50+        134.237288  120.000000  107.210526   92.203390  80.975610
#
#                              BS                         BodyTemp             \
# RiskLevel   low risk  high risk   mid risk  low risk   high risk   mid risk
# Age_Group
# 10-20      66.136691   8.694872   7.197030  7.228129  101.666667  99.376238
# 20-30      74.581560   9.209783   7.238917  7.165390   98.991304  98.666667
# 30-40      76.018519  11.271642   6.769091  7.025926   98.597015  98.854545
# 40-50      83.676471  14.103279  12.684211  7.747059   98.163934  98.000000
# 50+        73.421053  15.577966  10.012195  7.200000   98.101695  98.341463
#
#                       HeartRate
# RiskLevel   low risk  high risk   mid risk   low risk
# Age_Group
# 10-20      98.825899  73.564103  72.326733  72.237410
# 20-30      98.078014  78.000000  76.050000  74.063830
# 30-40      98.111111  77.582090  74.181818  70.166667
# 40-50      98.147059  80.065574  79.052632  73.117647
# 50+        98.342105  73.474576  70.975610  73.315789

# %%
# look at top 20 records of SystolicBP
def top(df, n=5,column='SystolicBP'):
    return df.sort_values(by=column)[-n:]
top(df,n=20)
# Out:
#      Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate  RiskLevel  \
# 426   40         140          100  13.0     101.0         66  high risk
# 467   50         140           90  15.0      98.0         90  high risk
# 428   36         140          100   6.8     102.0         76  high risk
# 432   40         140          100  13.0     101.0         66  high risk
# 436   35         140           80  13.0      98.0         70  high risk
# 440   23         140           90   6.8      98.0         70  high risk
# 456   23         140           90   6.8      98.0         70  high risk
# 422   36         140          100   6.8     102.0         76  high risk
# 452   25         140          100   6.8      98.0         80  high risk
# 451   48         140           90  15.0      98.0         90  high risk
# 130   40         160          100  19.0      98.0         77  high risk
# 689   40         160          100  19.0      98.0         77  high risk
# 123   40         160          100  19.0      98.0         77  high risk
# 166   40         160          100  19.0      98.0         77  high risk
# 538   40         160          100  19.0      98.0         77  high risk
# 362   40         160          100  19.0      98.0         77  high risk
# 583   40         160          100  19.0      98.0         77  high risk
# 961   40         160          100  19.0      98.0         77  high risk
# 262   40         160          100  19.0      98.0         77  high risk
# 994   40         160          100  19.0      98.0         77  high risk
#
#     Age_Group
# 426     40-50
# 467       50+
# 428     30-40
# 432     40-50
# 436     30-40
# 440     20-30
# 456     20-30
# 422     30-40
# 452     20-30
# 451     40-50
# 130     40-50
# 689     40-50
# 123     40-50
# 166     40-50
# 538     40-50
# 362     40-50
# 583     40-50
# 961     40-50
# 262     40-50
# 994     40-50

# %%
# correlation between age and health indicators
age_corr=lambda x: x.corrwith(x['Age'])
df.groupby('RiskLevel').apply(age_corr)
# Out:
#            Age  SystolicBP  DiastolicBP        BS  BodyTemp  HeartRate
# RiskLevel
# high risk  1.0    0.471108     0.448638  0.558726 -0.593412   0.057333
# mid risk   1.0    0.325287     0.292474  0.475955 -0.243922   0.012249
# low risk   1.0    0.265506     0.261877  0.086769 -0.122487   0.012658

# %%
# correlation between SystolicBP and DiastolicBP by RiskLevel
df.groupby('RiskLevel').apply(lambda g: g['SystolicBP'].corr(g['DiastolicBP']))
# Out:
# RiskLevel
# high risk    0.859587
# mid risk     0.558299
# low risk     0.804000
# dtype: float64

# %%
# Viz - Histograms for each variable

# %%
# Viz - scatter plots/boxplots for two or three variables

# %%
# Extract the numeric variables (including both float64 and int64)
df.loc[:,(df.dtypes=='float64')|(df.dtypes=='int64')]
# df.loc[:,(df.dtypes!='category')&(df.dtypes!='object')]
# Out:
#       Age  SystolicBP  DiastolicBP    BS  BodyTemp  HeartRate
# 0      25         130           80  15.0      98.0         86
# 1      35         140           90  13.0      98.0         70
# 2      29          90           70   8.0     100.0         80
# 3      30         140           85   7.0      98.0         70
# 4      35         120           60   6.1      98.0         76
# ...   ...         ...          ...   ...       ...        ...
# 1009   22         120           60  15.0      98.0         80
# 1010   55         120           90  18.0      98.0         60
# 1011   35          85           60  19.0      98.0         86
# 1012   43         120           90  18.0      98.0         70
# 1013   32         120           65   6.0     101.0         76
#
# [1014 rows x 6 columns]

# %%
# Correlation matrix
